# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

import matplotlib.pyplot as plt
from torchsummary import summary
import numpy as np

df = pd.read_csv("./car_evaluation.csv")

df
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['vhigh', 'vhigh.1', '2', '2.1', 'small', 'low', 'unacc'], dtype='object')

# %%
df.columns = ['price', 'maint', 'doors', 'persons', 'lug_capacity', 'safety','output']

df
# Out:
#       price  maint  doors persons lug_capacity safety output
# 0     vhigh  vhigh      2       2        small    med  unacc
# 1     vhigh  vhigh      2       2        small   high  unacc
# 2     vhigh  vhigh      2       2          med    low  unacc
# 3     vhigh  vhigh      2       2          med    med  unacc
# 4     vhigh  vhigh      2       2          med   high  unacc
# ...     ...    ...    ...     ...          ...    ...    ...
# 1722    low    low  5more    more          med    med   good
# 1723    low    low  5more    more          med   high  vgood
# 1724    low    low  5more    more          big    low  unacc
# 1725    low    low  5more    more          big    med   good
# 1726    low    low  5more    more          big   high  vgood
#
# [1727 rows x 7 columns]

# %%
columns = ['price', 'maint', 'doors', 'persons', 'lug_capacity', 'safety','output']

# %%
label_encoders = {}
for column in columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df
# Out:
#       price  maint  doors  persons  lug_capacity  safety  output
# 0         3      3      0        0             2       2       2
# 1         3      3      0        0             2       0       2
# 2         3      3      0        0             1       1       2
# 3         3      3      0        0             1       2       2
# 4         3      3      0        0             1       0       2
# ...     ...    ...    ...      ...           ...     ...     ...
# 1722      1      1      3        2             1       2       1
# 1723      1      1      3        2             1       0       3
# 1724      1      1      3        2             0       1       2
# 1725      1      1      3        2             0       2       1
# 1726      1      1      3        2             0       0       3
#
# [1727 rows x 7 columns]

# %%
df = df[df['output'].isin(['unacc', 'acc'])]
df['output'] = df['output'].map({'unacc': 0, 'acc': 1})

# %%
X = df.drop('output', axis=1).values
y = df['output'].values

# %%
X
# Out:
# array([], shape=(0, 6), dtype=int32)

# %%
y
# Out:
# array([], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 5
#       2 from sklearn.model_selection import train_test_split
#       4 scaler = StandardScaler()
# ----> 5 X = scaler.fit_transform(X)
#       7 # Split the dataset into training and test sets
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# File c:\Users\syjwk\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape,
# Out:
# (torch.Size([1381, 6]),
#  torch.Size([346, 6]),
#  torch.Size([1381]),
#  torch.Size([346]))

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)  # ✅ 핵심
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)
# Out:
# C:\Users\syjwk\AppData\Local\Temp\ipykernel_21616\3900005444.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train = torch.tensor(X_train, dtype=torch.float32)
# C:\Users\syjwk\AppData\Local\Temp\ipykernel_21616\3900005444.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test = torch.tensor(X_test, dtype=torch.float32)
# C:\Users\syjwk\AppData\Local\Temp\ipykernel_21616\3900005444.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)  # ✅ 핵심
# ...

# %%
train_dataset = TensorDataset(X_train, y_train)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = TensorDataset(X_test, y_test)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([1381, 6]),
#  torch.Size([346, 6]),
#  torch.Size([1381]),
#  torch.Size([346]))

# %%
class CarEvaluationBinary(nn.Module):
    def __init__(self):
        super(CarEvaluationBinary, self).__init__()
        self.fc1 = nn.Linear(6, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)  

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))  # BCELoss를 사용할 것이므로 sigmoid 포함
        return x

# %%
model = CarEvaluationBinary()  # 모델 먼저 생성!
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_dataloader:
        outputs = model(inputs)
        preds = (outputs > 0.5).int()
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# classification report
print(classification_report(all_labels, all_preds, target_names=['unacc', 'acc']))

# confusion matrix
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['unacc', 'acc'], yticklabels=['unacc', 'acc'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 16
#      14 # Forward pass
#      15 outputs = model(inputs)
# ---> 16 loss = criterion(outputs, labels)
#      18 # Backward pass and optimize
#      19 loss.backward()
#
# File c:\Users\syjwk\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\syjwk\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
# ...
